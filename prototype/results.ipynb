# %% [markdown]
# # Prototype Results
#
# ## 3 vs 8, 4 qubits (4 PCA features)
# - Classical RBF SVM: 91% accuracy, 0.006s training
# - Quantum Kernel SVM: 45% accuracy, 77s training

# %% [markdown]
# ## 3 vs 8, 8 qubits (8 PCA features)
# - Classical RBF SVM: 98% accuracy, 0.009s training
# - Quantum Kernel SVM: 51% accuracy, 728s training (12 minutes)

# %% [markdown]
# ## 0 vs 1, 4 qubits (4 PCA features)
#
# - Classical RBF SVM: 100% accuracy, 0.007s training
# - Quantum Kernel SVM depth 1: 53% accuracy, 77.9s training
# - Quantum Kernel SVM depth 2: 46% accuracy, 118.4s training
